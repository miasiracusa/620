# %% [markdown]
# #### Data 620 - Final Project <br>July 17, 2019<br>Team 2: <ul><li>Anthony Munoz</li> <li>Katie Evers</li> <li>Juliann McEachern</li> <li>Mia Siracusa</li></ul>
#
# <h1 align="center">Final Project</h1>
#
#
# ## Project Overview
#
# **Proposal:** Your proposal should describe at a high level what you’re seeking to accomplish, and your motivation for performing this analysis. A guiding question or hypothesis to test is one good way to start. If you are going to work in a small group (encouraged!), you should also list your partners’ names.
#
# You should briefly describe:
#
# 1.  Your data sources;
# 2.  Plan for doing the work
# 3.  Up front concerns.
# 4.  Describe the roles and responsibilities of each group member.
#
# We’ll treat this proposal as a planning document, not a blue print containing "firm, fixed requirements."
#
# Your project should incorporate one or both of the two main themes of this course: network analysis and text processing. You need to show all of your work in a coherent workflow, and in a reproducible format, such as an IPython Notebook or an R Markdown document. If you are building a model or models, explain how you evaluate the “goodness” of the chosen model and parameters.
#
# #### Dependencies

# %%
import pandas as pd, numpy as np

from sodapy import Socrata
from socrata_credentials import app_token

# %% [markdown]
# #### Data Acquisition
#
# We established a client connection with the Chicago API using `Socrata` to obtain our data. Results were stored in `pandas` dataframes.

# %%
# Establish connection variables 
domain = "data.cityofchicago.org"; req_case_summary = "mft5-nfa8"; req_complainant  = "vnz2-rmie"; req_officer = "ufxy-tgry"

# Initiate client connection
client = Socrata(domain = domain, app_token = app_token)

# Obtain results from API request
case_summary_results = client.get(req_case_summary, limit=100000)
complainant_results = client.get(req_complainant, limit=100000)
officer_results = client.get(req_officer, limit=100000)

# Close client connection
client.close()

# Store results in pandas dataframes
cs_df = pd.DataFrame.from_dict(case_summary_results)
cmpl_df = pd.DataFrame.from_dict(complainant_results)
off_df = pd.DataFrame.from_dict(officer_results)

# %%
print("DATAFRAME SHAPE:", "\n  By Case Summary",cs_df.shape,"\n  By Complainant",cmpl_df.shape,"\n  By Officer",off_df.shape,)
# Out:
# DATAFRAME SHAPE:
#   By Case Summary (81491, 19)
#   By Complainant (86476, 15)
#   By Officer (91880, 16)

# %% [markdown]
# #### Data Transformations
#
# The log number (`log_no`) field provides a unique id of all incidences in which we can join our dataframe on.

# %%
cs_df
# Out:
#       age_of_complainants                       age_of_involved_officers  \
# 0                     NaN                                            NaN
# 1                     NaN                                            NaN
# 2                     NaN                                            NaN
# 3                     NaN                                            NaN
# 4           40-49 | 20-29                                            NaN
# 5                     NaN                                            NaN
# 6                     NaN                                            NaN
# 7                     NaN                                            NaN
# 8                     NaN                                            NaN
# 9                     NaN                                            NaN
# 10                    NaN                                            NaN
# 11                    NaN                                            NaN
# 12                    NaN                                            NaN
# 13                    NaN                                            NaN
# 14                    NaN                                            NaN
# 15                    NaN                                            NaN
# 16                  20-29                                            NaN
# 17                    NaN                                            NaN
# 18                    NaN                                            NaN
# 19                    NaN                                            NaN
# 20                    NaN                                            NaN
# 21                    NaN                                            NaN
# 22                  20-29                                            NaN
# 23                Unknown                                          30-39
# 24                Unknown  30-39 | 20-29 | 30-39 | 50-59 | 50-59 | 40-49
# 25                  20-29                                            NaN
# 26                  30-39                                  40-49 | 40-49
# 27          20-29 | 30-39                                          50-59
# 28                Unknown                                            NaN
# 29                    NaN                                            NaN
# ...                   ...                                            ...
# 81461     20-29 | Unknown                  40-49 | 30-39 | 50-59 | 30-39
# 81462       20-29 | 20-29                                  30-39 | 30-39
# 81463                 NaN                                            NaN
# 81464                 NaN                                            NaN
# 81465                 NaN                                            NaN
# 81466                 NaN                                            NaN
# 81467             Unknown                                          50-59
# 81468                 NaN                                            NaN
# 81469                 NaN                                            NaN
# 81470                 NaN                                            NaN
# 81471                 NaN                                            NaN
# 81472                 NaN                                            NaN
# 81473                 NaN                                            NaN
# 81474               20-29                                          30-39
# 81475               30-39                                            NaN
# 81476                0-19                                            NaN
# 81477                 NaN                                            NaN
# 81478                 NaN                                            NaN
# 81479               20-29                                          30-39
# 81480             Unknown                                  20-29 | 20-29
# 81481                 NaN                                            NaN
# 81482                 NaN                                            NaN
# 81483                 NaN                                            NaN
# 81484                 NaN                                            NaN
# 81485                 NaN                                            NaN
# 81486                 NaN                                            NaN
# 81487                 NaN                                            NaN
# 81488       20-29 | 20-29                                          30-39
# 81489                 NaN                                            NaN
# 81490               30-39                                            NaN
#
#       assignment         beat  case_type           complaint_date  \
# 0            BIA          NaN        NaN  2019-01-12T10:44:54.000
# 1            BIA          NaN        NaN  2019-01-12T10:24:30.000
# 2            BIA          NaN        NaN  2019-01-11T22:30:46.000
# 3            BIA          NaN        NaN  2019-01-11T15:29:31.000
# 4           COPA         1132  Complaint  2019-01-11T15:18:16.000
# 5            BIA          NaN        NaN  2019-01-11T14:48:54.000
# 6            BIA          NaN        NaN  2019-01-11T14:10:36.000
# 7            BIA          NaN        NaN  2019-01-11T14:06:40.000
# 8            BIA          NaN        NaN  2019-01-11T13:37:44.000
# 9            BIA          NaN        NaN  2019-01-11T12:35:40.000
# 10           BIA          NaN        NaN  2019-01-11T11:02:28.000
# 11           BIA          NaN        NaN  2019-01-11T11:01:49.000
# 12           BIA          NaN        NaN  2019-01-11T11:01:09.000
# 13           BIA          NaN        NaN  2019-01-11T09:29:33.000
# 14           BIA          NaN        NaN  2019-01-11T07:07:03.000
# 15           BIA          NaN        NaN  2019-01-11T02:23:20.000
# 16          COPA         1114  Complaint  2019-01-11T00:50:55.000
# 17           BIA          NaN        NaN  2019-01-10T18:04:00.000
# 18           BIA          NaN        NaN  2019-01-10T17:44:48.000
# 19           BIA          NaN        NaN  2019-01-10T14:40:48.000
# 20           BIA          NaN        NaN  2019-01-10T14:34:27.000
# 21           BIA          NaN        NaN  2019-01-10T14:20:49.000
# 22          COPA          411  Complaint  2019-01-10T14:09:40.000
# 23          COPA         1933  Complaint  2019-01-10T13:55:51.000
# 24          COPA          835  Complaint  2019-01-10T13:24:46.000
# 25          COPA          414  Complaint  2019-01-10T13:18:25.000
# 26          COPA          311  Complaint  2019-01-10T13:13:36.000
# 27          COPA          233  Complaint  2019-01-10T12:56:23.000
# 28          COPA         2535  Complaint  2019-01-10T12:49:40.000
# 29           BIA          NaN        NaN  2019-01-10T12:25:39.000
# ...          ...          ...        ...                      ...
# 81461       IPRA          411  Complaint  2007-09-02T13:18:55.000
# 81462       IPRA         1011  Complaint  2007-09-02T11:56:46.000
# 81463        BIA          NaN        NaN  2007-09-02T11:02:32.000
# 81464        BIA          NaN        NaN  2007-09-02T09:33:13.000
# 81465        BIA          NaN        NaN  2007-09-02T08:55:09.000
# 81466        BIA          NaN        NaN  2007-09-02T05:55:14.000
# 81467       IPRA         2212  Complaint  2007-09-01T21:22:17.000
# 81468        BIA          NaN        NaN  2007-09-01T20:36:23.000
# 81469        BIA          NaN        NaN  2007-09-01T20:16:45.000
# 81470        BIA          NaN        NaN  2007-09-01T20:08:39.000
# 81471        BIA          NaN        NaN  2007-09-01T19:50:51.000
# 81472        BIA          NaN        NaN  2007-09-01T19:31:24.000
# 81473        BIA          NaN        NaN  2007-09-01T19:18:51.000
# 81474       IPRA          523  Complaint  2007-09-01T19:03:03.000
# 81475       IPRA         2024  Complaint  2007-09-01T18:55:06.000
# 81476       IPRA         2512  Complaint  2007-09-01T17:02:20.000
# 81477        BIA          NaN        NaN  2007-09-01T16:17:18.000
# 81478        BIA          NaN        NaN  2007-09-01T15:11:28.000
# 81479       IPRA  1135 | 1134  Complaint  2007-09-01T15:06:08.000
# 81480       IPRA         1132  Complaint  2007-09-01T14:59:50.000
# 81481        BIA          NaN        NaN  2007-09-01T14:35:37.000
# 81482        BIA          NaN        NaN  2007-09-01T14:16:42.000
# 81483        BIA          NaN        NaN  2007-09-01T12:35:40.000
# 81484        BIA          NaN        NaN  2007-09-01T12:08:03.000
# 81485        BIA          NaN        NaN  2007-09-01T11:12:44.000
# 81486        BIA          NaN        NaN  2007-09-01T11:07:01.000
# 81487        BIA          NaN        NaN  2007-09-01T07:36:00.000
# 81488       IPRA         1933  Complaint  2007-09-01T04:16:33.000
# 81489        BIA          NaN        NaN  2007-09-01T01:53:51.000
# 81490       IPRA          433  Complaint  2007-09-01T00:34:36.000
#
#       complaint_day complaint_hour complaint_month  \
# 0                 7             10               1
# 1                 7             10               1
# 2                 6             22               1
# 3                 6             15               1
# 4                 6             15               1
# 5                 6             14               1
# 6                 6             14               1
# 7                 6             14               1
# 8                 6             13               1
# 9                 6             12               1
# 10                6             11               1
# 11                6             11               1
# 12                6             11               1
# 13                6              9               1
# 14                6              7               1
# 15                6              2               1
# 16                6              0               1
# 17                5             18               1
# 18                5             17               1
# 19                5             14               1
# 20                5             14               1
# 21                5             14               1
# 22                5             14               1
# 23                5             13               1
# 24                5             13               1
# 25                5             13               1
# 26                5             13               1
# 27                5             12               1
# 28                5             12               1
# 29                5             12               1
# ...             ...            ...             ...
# 81461             1             13               9
# 81462             1             11               9
# 81463             1             11               9
# 81464             1              9               9
# 81465             1              8               9
# 81466             1              5               9
# 81467             7             21               9
# 81468             7             20               9
# 81469             7             20               9
# 81470             7             20               9
# 81471             7             19               9
# 81472             7             19               9
# 81473             7             19               9
# 81474             7             19               9
# 81475             7             18               9
# 81476             7             17               9
# 81477             7             16               9
# 81478             7             15               9
# 81479             7             15               9
# 81480             7             14               9
# 81481             7             14               9
# 81482             7             14               9
# 81483             7             12               9
# 81484             7             12               9
# 81485             7             11               9
# 81486             7             11               9
# 81487             7              7               9
# 81488             7              4               9
# 81489             7              1               9
# 81490             7              0               9
#
#                  current_category         current_status   finding_code  \
# 0                             NaN                    NaN            NaN
# 1                             NaN                    NaN            NaN
# 2                             NaN                    NaN            NaN
# 3                             NaN                    NaN            NaN
# 4                 Excessive Force  Pending Investigation            NaN
# 5                             NaN                    NaN            NaN
# 6                             NaN                    NaN            NaN
# 7                             NaN                    NaN            NaN
# 8                             NaN                    NaN            NaN
# 9                             NaN                    NaN            NaN
# 10                            NaN                    NaN            NaN
# 11                            NaN                    NaN            NaN
# 12                            NaN                    NaN            NaN
# 13                            NaN                    NaN            NaN
# 14                            NaN                    NaN            NaN
# 15                            NaN                    NaN            NaN
# 16                Excessive Force  Pending Investigation            NaN
# 17                            NaN                    NaN            NaN
# 18                            NaN                    NaN            NaN
# 19                            NaN                    NaN            NaN
# 20                            NaN                    NaN            NaN
# 21                            NaN                    NaN            NaN
# 22          Operational Violation  Pending Investigation            NaN
# 23     Unlawful Denial of Counsel  Pending Investigation            NaN
# 24                    Civil Suits  Pending Investigation            NaN
# 25              Search or Seizure  Pending Investigation            NaN
# 26                    Civil Suits  Pending Investigation            NaN
# 27                    Civil Suits  Pending Investigation            NaN
# 28                    Civil Suits  Pending Investigation            NaN
# 29                            NaN                    NaN            NaN
# ...                           ...                    ...            ...
# 81461             Excessive Force                 Closed  NOT SUSTAINED
# 81462             Excessive Force                 Closed  NOT SUSTAINED
# 81463                         NaN                    NaN            NaN
# 81464                         NaN                    NaN            NaN
# 81465                         NaN                    NaN            NaN
# 81466                         NaN                    NaN            NaN
# 81467       Operational Violation                 Closed      SUSTAINED
# 81468                         NaN                    NaN            NaN
# 81469                         NaN                    NaN            NaN
# 81470                         NaN                    NaN            NaN
# 81471                         NaN                    NaN            NaN
# 81472                         NaN                    NaN            NaN
# 81473                         NaN                    NaN            NaN
# 81474             Excessive Force                 Closed  NOT SUSTAINED
# 81475             Excessive Force                 Closed     No Finding
# 81476             Excessive Force                 Closed      UNFOUNDED
# 81477                         NaN                    NaN            NaN
# 81478                         NaN                    NaN            NaN
# 81479               Miscellaneous                 Closed  NOT SUSTAINED
# 81480  Death or Injury In Custody                 Closed      UNFOUNDED
# 81481                         NaN                    NaN            NaN
# 81482                         NaN                    NaN            NaN
# 81483                         NaN                    NaN            NaN
# 81484                         NaN                    NaN            NaN
# 81485                         NaN                    NaN            NaN
# 81486                         NaN                    NaN            NaN
# 81487                         NaN                    NaN            NaN
# 81488               Miscellaneous                 Closed  NOT SUSTAINED
# 81489                         NaN                    NaN            NaN
# 81490               Miscellaneous                 Closed   NO AFFIDAVIT
#
#         log_no police_shooting  \
# 0      1092329             NaN
# 1      1092328             NaN
# 2      1092327             NaN
# 3      1092326             NaN
# 4      1092325              No
# 5      1092324             NaN
# 6      1092323             NaN
# 7      1092322             NaN
# 8      1092320             NaN
# 9      1092319             NaN
# 10     1092318             NaN
# 11     1092317             NaN
# 12     1092316             NaN
# 13     1092315             NaN
# 14     1092314             NaN
# 15     1092313             NaN
# 16     1092312              No
# 17     1092311             NaN
# 18     1092310             NaN
# 19     1092309             NaN
# 20     1092308             NaN
# 21     1092307             NaN
# 22     1092306              No
# 23     1092305              No
# 24     1092304              No
# 25     1092303              No
# 26     1092302              No
# 27     1092301              No
# 28     1092300              No
# 29     1092299             NaN
# ...        ...             ...
# 81461  1008928              No
# 81462  1008927              No
# 81463  1008926             NaN
# 81464  1008925             NaN
# 81465  1008924             NaN
# 81466  1008923             NaN
# 81467  1008922              No
# 81468  1008921             NaN
# 81469  1008920             NaN
# 81470  1008919             NaN
# 81471  1008918             NaN
# 81472  1008917             NaN
# 81473  1008916             NaN
# 81474  1008915              No
# 81475  1008914              No
# 81476  1008913              No
# 81477  1008912             NaN
# 81478  1008911             NaN
# 81479  1008910              No
# 81480  1008909              No
# 81481  1008908             NaN
# 81482  1008907             NaN
# 81483  1008906             NaN
# 81484  1008905             NaN
# 81485  1008904             NaN
# 81486  1008903             NaN
# 81487  1008902             NaN
# 81488  1008901              No
# 81489  1008900             NaN
# 81490  1008899              No
#
#                                     race_of_complainants  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      African American / Black | African American / ...
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                              African American / Black
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                              African American / Black
# 23                                              Hispanic
# 24                                               Unknown
# 25                              African American / Black
# 26                              African American / Black
# 27                                   Hispanic | Hispanic
# 28                                               Unknown
# 29                                                   NaN
# ...                                                  ...
# 81461  African American / Black | African American / ...
# 81462  African American / Black | African American / ...
# 81463                                                NaN
# 81464                                                NaN
# 81465                                                NaN
# 81466                                                NaN
# 81467                                              White
# 81468                                                NaN
# 81469                                                NaN
# 81470                                                NaN
# 81471                                                NaN
# 81472                                                NaN
# 81473                                                NaN
# 81474                           African American / Black
# 81475                           African American / Black
# 81476                                              White
# 81477                                                NaN
# 81478                                                NaN
# 81479                           African American / Black
# 81480                           African American / Black
# 81481                                                NaN
# 81482                                                NaN
# 81483                                                NaN
# 81484                                                NaN
# 81485                                                NaN
# 81486                                                NaN
# 81487                                                NaN
# 81488  African American / Black | African American / ...
# 81489                                                NaN
# 81490                                           Hispanic
#
#                                race_of_involved_officers sex_of_complainants  \
# 0                                                    NaN                 NaN
# 1                                                    NaN                 NaN
# 2                                                    NaN                 NaN
# 3                                                    NaN                 NaN
# 4                                                    NaN       Female | Male
# 5                                                    NaN                 NaN
# 6                                                    NaN                 NaN
# 7                                                    NaN                 NaN
# 8                                                    NaN                 NaN
# 9                                                    NaN                 NaN
# 10                                                   NaN                 NaN
# 11                                                   NaN                 NaN
# 12                                                   NaN                 NaN
# 13                                                   NaN                 NaN
# 14                                                   NaN                 NaN
# 15                                                   NaN                 NaN
# 16                                                   NaN                Male
# 17                                                   NaN                 NaN
# 18                                                   NaN                 NaN
# 19                                                   NaN                 NaN
# 20                                                   NaN                 NaN
# 21                                                   NaN                 NaN
# 22                                                   NaN                Male
# 23                             Asian or Pacific Islander                Male
# 24     Asian or Pacific Islander | White | Asian or P...                Male
# 25                                                   NaN              Female
# 26                                   Hispanic | Hispanic                Male
# 27                                                 White         Male | Male
# 28                                                   NaN                Male
# 29                                                   NaN                 NaN
# ...                                                  ...                 ...
# 81461                   White | White | Hispanic | White     Female | Female
# 81462                                      White | White         Male | Male
# 81463                                                NaN                 NaN
# 81464                                                NaN                 NaN
# 81465                                                NaN                 NaN
# 81466                                                NaN                 NaN
# 81467                                              White              Female
# 81468                                                NaN                 NaN
# 81469                                                NaN                 NaN
# 81470                                                NaN                 NaN
# 81471                                                NaN                 NaN
# 81472                                                NaN                 NaN
# 81473                                                NaN                 NaN
# 81474                           African American / Black                Male
# 81475                                                NaN              Female
# 81476                                                NaN              Female
# 81477                                                NaN                 NaN
# 81478                                                NaN                 NaN
# 81479                                              White                Male
# 81480                                      White | White                Male
# 81481                                                NaN                 NaN
# 81482                                                NaN                 NaN
# 81483                                                NaN                 NaN
# 81484                                                NaN                 NaN
# 81485                                                NaN                 NaN
# 81486                                                NaN                 NaN
# 81487                                                NaN                 NaN
# 81488                                              White     Female | Female
# 81489                                                NaN                 NaN
# 81490                                                NaN                Male
#
#                         sex_of_involved_officers  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# 10                                           NaN
# 11                                           NaN
# 12                                           NaN
# 13                                           NaN
# 14                                           NaN
# 15                                           NaN
# 16                                           NaN
# 17                                           NaN
# 18                                           NaN
# 19                                           NaN
# 20                                           NaN
# 21                                           NaN
# 22                                           NaN
# 23                                          Male
# 24     Male | Female | Male | Male | Male | Male
# 25                                           NaN
# 26                                 Female | Male
# 27                                        Female
# 28                                           NaN
# 29                                           NaN
# ...                                          ...
# 81461                Male | Female | Male | Male
# 81462                                Male | Male
# 81463                                        NaN
# 81464                                        NaN
# 81465                                        NaN
# 81466                                        NaN
# 81467                                       Male
# 81468                                        NaN
# 81469                                        NaN
# 81470                                        NaN
# 81471                                        NaN
# 81472                                        NaN
# 81473                                        NaN
# 81474                                       Male
# 81475                                        NaN
# 81476                                        NaN
# 81477                                        NaN
# 81478                                        NaN
# 81479                                     Female
# 81480                                Male | Male
# 81481                                        NaN
# 81482                                        NaN
# 81483                                        NaN
# 81484                                        NaN
# 81485                                        NaN
# 81486                                        NaN
# 81487                                        NaN
# 81488                                       Male
# 81489                                        NaN
# 81490                                        NaN
#
#                       years_on_force_of_officers
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
# 10                                           NaN
# 11                                           NaN
# 12                                           NaN
# 13                                           NaN
# 14                                           NaN
# 15                                           NaN
# 16                                           NaN
# 17                                           NaN
# 18                                           NaN
# 19                                           NaN
# 20                                           NaN
# 21                                           NaN
# 22                                           NaN
# 23                                         10-14
# 24     5-9 | 0-4 | 10-14 | 15-19 | 20-24 | 25-29
# 25                                           NaN
# 26                                   10-14 | 5-9
# 27                                         20-24
# 28                                           NaN
# 29                                           NaN
# ...                                          ...
# 81461              10-14 | 15-19 | 10-14 | 10-14
# 81462                                  0-4 | 0-4
# 81463                                        NaN
# 81464                                        NaN
# 81465                                        NaN
# 81466                                        NaN
# 81467                                      15-19
# 81468                                        NaN
# 81469                                        NaN
# 81470                                        NaN
# 81471                                        NaN
# 81472                                        NaN
# 81473                                        NaN
# 81474                                        5-9
# 81475                                        NaN
# 81476                                        NaN
# 81477                                        NaN
# 81478                                        NaN
# 81479                                      10-14
# 81480                                  0-4 | 5-9
# 81481                                        NaN
# 81482                                        NaN
# 81483                                        NaN
# 81484                                        NaN
# 81485                                        NaN
# 81486                                        NaN
# 81487                                        NaN
# 81488                                        5-9
# 81489                                        NaN
# 81490                                        NaN
#
# [81491 rows x 19 columns]

# %% [markdown]
# ## Network Analysis

# %% [markdown]
# ## Text Processing
